# %% [markdown]
# <a href="https://colab.research.google.com/github/26041633-max/Fundamentos/blob/main/Unidad%201/Plactica%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ingenieria de inteligencia artificail
# #Fundamentos de programacion
#
#
# ##unidad 1
#
#
# ###plactica 1 introduccion al lenguaje de programacion python
# docente: * José Gabriel Rodríguez Rivas*
# alumno: Manuel Alan Garcia Garcia
# Numero de control:26041633

# %%
# we need to use "" to strim of alphanumeric caracters we use the [] to create a list of data base
alumnos = ["juan", "diana", "ana"]
print(alumnos[1])
print(alumnos [2])
print(alumnos [0])
# Out:
# diana
# ana
# juan

# %%
#:3 🐱
alumnos [1]= "Angel"
print(alumnos[1])
# Out:
# Angel

# %%
#append add a element at the list 🐱
alumnos.append("karla")
print(alumnos)
# Out:
# ['juan', 'Angel', 'ana', 'karla']

# %%
# insert add a element in a specific position of the list 🐱
alumnos.insert(2, "alison")
print(alumnos)
# Out:
# ['juan', 'Angel', 'alison', 'ana', 'karla']

# %%
#function to erase data base 🐱
alumnos.remove("ana")
print (alumnos)
alumnos.pop((1))
print (alumnos)
del alumnos[0]
print (alumnos)
# Out:
# ['juan', 'Angel', 'alison', 'karla']
# ['juan', 'alison', 'karla']
# ['alison', 'karla']

# %%
# this fuction is to know how many slement have a list 🐱
print(len(alumnos))
# Out:
# 2

# %%
alumnos.append("karla")
alumnos.insert(2, "alison")
for q in alumnos:
    print(q)
# Out:
# alison
# karla
# alison
# karla

# %%
# break is to stop the funtion for ultil a specific condition🐱
print(alumnos)
for q in alumnos:
  print(q)
  if q == "karla":
    break
# Out:
# ['alison', 'karla', 'alison', 'karla']
# alison
# karla

# %%
sof = ["python","autocad", "c++", "autodesk", "java"]
print (sof)
# Out:
# ['python', 'autocad', 'c++', 'autodesk', 'java']

# %%
if "autodesk" in sof:
  print("si esta 🐱")
else:
  print("no esta 😿")
# Out:
# si esta 🐱

# %%
#another way to print a list
for x in range(len(sof)):
  print(sof[x])
# Out:
# python
# autocad
# c++
# autodesk
# java
