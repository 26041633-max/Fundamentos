# %% [markdown]
# <a href="https://colab.research.google.com/github/26041633-max/Fundamentos/blob/main/22_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alumnos = ["26039232","26938293","26384729","26039232","26938293","26384729","26039232","26938293","26384729"]
computadoras = [" PC-LC1-01"," PC-LC1-02"," PC-LC1-03"," PC-LC1-04"," PC-LC1-01"," PC-LC1-02"," PC-LC1-03"," PC-LC1-04",
                " PC-LC1-06"," PC-LC1-07"," PC-LC1-08"," PC-LC1-09"," PC-LC1-10"," PC-LC1-11"," PC-LC1-12"," PC-LC1-13",
                " PC-LC1-14"," PC-LC1-15"," PC-LC1-16"," PC-LC1-17"," PC-LC1-18"," PC-LC1-19"," PC-LC1-20"," PC-LC1-21"]
aulas = ["","","",""]
software = ["Pyton","Autocad","Autodesk","Visual estudio","Java","Html5"]
Estado = ["Disponible","No disponible","Reservada","Mantenimiento"]

# %%
computadora = []
computadoras = []
estados = []
aulas = []
opcion = int(input("Por favor, ingrese una opción (ej: 3 para solicitar préstamo): "))
if opcion == 3:
  print ("\n-- solicitar prestamo --")
  num_control = input ("\nIngrese el numero de control: ")
  encontrado1 = False
  id_computadora = input("ingrese el id de la compuadora: ")
  encontrado2 = False
  for i in range (len(computadora)):
    if computadora[i] == id_computadora:
      encontrado2 = True
      if estados[i] == "Disponible":
        estados[i] = "prestada"
        print("prestamo registrado correctamente")
        print("computadora:", computadoras[i])
        print("aula:", aulas[i])
      else:
        print("la computador no esta disponible")
        # The following 'if' blocks for 'encontrado2' and 'encontrado1'
        # are logically questionable at this position (inside the 'else'
        # of a 'Disponible' check), but are kept as per the original
        # structure for now to focus on direct syntax fixes.
        if encontrado2 == False:
          print("la computadora no existe")
          if encontrado1 == False:
            print("el numero de control no existe")
# Out:
# Por favor, ingrese una opción (ej: 3 para solicitar préstamo): 3
#
# -- solicitar prestamo --
#
# Ingrese el numero de control: 32
# ingrese el id de la compuadora: 23

# %%
if opcion == 1
  print("/n--- Computadora ---")
  for 1 in range (len(computadoras)):
    print("aula", aulas [1])
    print()

    PC-LC1-01 / SOFTWARE:

# %%
P = "Python"
pro= input("Escriba el programa a buscar")
if P == pro:
  print("Programa encontrado")
else:
  print("Programa no encontrado")
print("variables originales", P, pro)
print("variables originales", P.lower(), pro.lower())
# Out:
# Escriba el programa a buscarpyton
# Programa no encontrado
# variables originales Python pyton
# variables originales python pyton

# %% [markdown]
# 23/09/2026

# %%
# Version 1 - Progama de Prestamos
#-------------------------------------------------------------------------------
# Lista de alumnos
alumnos = ["26040200", "26040201", "26040202", "26040203", "26040204"]
# Cada valor en la lista de computadoras tiene su lista correspondiente con el
# aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = [
    "PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
    "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
    "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"
]
aulas = [
    "LC1", "LC1", "LC1",
    "LC2", "LC2", "LC2",
    "LC3", "LC3", "LC3", "LC3"
]
software = [
    "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
    "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
    "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Python, VS Code"
]
estados = [
    "Disponible", "Prestada", "Reservada",
    "Disponible", "Prestada", "Disponible",
    "Disponible", "Prestada", "Reservada", "Mantenimiento"
]
# MENÚ PRINCIPAL
# Usamos un ciclo while que se repetira indefinidamente hasta que el usuario
# teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
    print("\n-----------------------------------")
    print(" SISTEMA DE PRESTAMOS ")
    print("------------------------------------")
    print("1. Consultar computadoras")
    print("2. Buscar por software")
    print("3. Solicitar préstamo")
    print("4. Devolver computadora")
    print("5. Crear reservación")
    print("6. Agregar computadora")
    print("7. Salir")
    print("--------------------------------------")

    try:
        opcion = int(input("Seleccione una opción: "))
    except ValueError:
        print("\nOpción no válida. Ingrese un número.")
        continue

    # 1. Consultar computadoras
    # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
    # toda la lista de computadoras e imprime los valores de las demás listas
    if opcion == 1:
        print("\n--- COMPUTADORAS ---")
        for i in range(len(computadoras)):
            print("Aula:", aulas[i], "| ID:", computadoras[i], "| Software:", software[i], "| Estado:", estados[i])

    # 2. Buscar por software
    elif opcion == 2:
        programa = input("\nIngrese el software que desea buscar: ")
        print("\n--- RESULTADOS ---")
        encontrado = False
        for i in range(len(computadoras)):
            # La función (lower) convierte a minúscula el texto
            if programa.lower() in software[i].lower():
                print("ID:", computadoras[i])
                print("Aula:", aulas[i])
                print("Software:", software[i])
                print("Estado:", estados[i])
                print("-" * 20)
                encontrado = True

        if encontrado == False:
            print("No se encontraron computadoras con ese software.")

    # 3. Solicitar préstamo
    elif opcion == 3:
        print("\n--- SOLICITAR PRÉSTAMO ---")
        num_control = input("Numero de control del alumno: ")
        if num_control in alumnos:
            print("Si existe el alumno")
            programa = input("Que Programa necesita: ")

            asignado = False
            for i in range(len(computadoras)):
                if programa.lower() in software[i].lower():
                    if estados[i] == "Disponible":
                        estados[i] = "Prestada"
                        print("Prestamo registrado correctamente")
                        print("Computadora Asignada:", computadoras[i])
                        print("Aula Asignada:", aulas[i])
                        asignado = True
                        break

            if not asignado:
                print("No hay computadoras disponibles con ese programa.")
        else:
            print("El alumno no existe en el sistema")

    # 4. Devolver computadora
    elif opcion == 4:
        print("\n--- DEVOLVER COMPUTADORA ---")
        id_comp = input("Ingrese el ID de la computadora a devolver: ")
        if id_comp in computadoras:
            idx = computadoras.index(id_comp)
            if estados[idx] == "Prestada":
                estados[idx] = "Disponible"
                print("Computadora devuelta exitosamente.")
            else:
                print("La computadora no se encuentra en estado 'Prestada'.")
        else:
            print("El ID de la computadora no existe.")

    # 5. Crear reservación
    elif opcion == 5:
        print("\n--- CREAR RESERVACIÓN ---")
        num_control = input("Numero de control del alumno: ")
        if num_control in alumnos:
            id_comp = input("Ingrese el ID de la computadora a reservar: ")
            if id_comp in computadoras:
                idx = computadoras.index(id_comp)
                if estados[idx] == "Disponible":
                    estados[idx] = "Reservada"
                    print("Reservación creada con éxito.")
                else:
                    print("La computadora no está disponible para reservar.")
            else:
                print("El ID de la computadora no existe.")
        else:
            print("El alumno no existe en el sistema")

    # 6. Agregar computadora
    elif opcion == 6:
        print("\n--- AGREGAR COMPUTADORA ---")
        id_computadora = input("ID de la computadora: ")
        aula = input("Aula: ")
        programas = input("Software instalado: ")
        computadoras.append(id_computadora)
        aulas.append(aula)
        software.append(programas)
        estados.append("Disponible")
        print("\nComputadora agregada correctamente.")

    # 7. Salir
    elif opcion == 7:
        print("\nGracias por utilizar el sistema.")
        print("(/\\_/\\)")
        print("( o.o )")
        print("(> ^ <)")
        break
    else:
        print("\nOpción no válida.")
# Out:
# -----------------------------------
#  SISTEMA DE PRESTAMOS
# ------------------------------------
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# --------------------------------------
# Seleccione una opción: 4
#
# --- DEVOLVER COMPUTADORA ---
# Ingrese el ID de la computadora a devolver: e
# El ID de la computadora no existe.
#
# -----------------------------------
#  SISTEMA DE PRESTAMOS
# ------------------------------------
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# --------------------------------------
# Seleccione una opción: 7
#
# Gracias por utilizar el sistema.
# (/\_/\)
# ( o.o )
# (> ^ <)
